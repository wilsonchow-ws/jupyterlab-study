# %%
#Breast Cancer Analysis
import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"
import numpy as np
import pandas as pd

# %%
bcancer= pd.read_csv('breast-cancer-wisconsin_wdbc.csv')

# %%
bcancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   %id                                569 non-null    int64
#  1   diagnosis (M=malignant; B=benign)  569 non-null    object
#  2   radius (nucA)                      569 non-null    float64
#  3   texture (nucA)                     569 non-null    float64
#  4   perimeter (nucA)                   569 non-null    float64
#  5   area (nucA)                        569 non-null    float64
#  6   smoothness (nucA)                  569 non-null    float64
#  7   compactness (nucA)                 569 non-null    float64
#  8   concavity (nucA)                   569 non-null    float64
#  9   concave points (nucA)              569 non-null    float64
#  10  symmetry (nucA)                    569 non-null    float64
# ...

# %%
#bcancer.describe()
#bcancer.shape
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

x = np.array(bcancer[['compactness (nucA)']])
y = np.array(bcancer[['fractal dimension (nucA)']])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("compactness (nucA)", fontdict = font2)
plt.ylabel("fractal dimension (nucA)", fontdict = font2)
plt.title("compactness vs fractal dimension (nucA) (benign)", fontdict = font1)

colors = bcancer['diagnosis (M=malignant; B=benign)'].map({'B': 'blue', 'M': 'red'})

plt.scatter(x, y, color=colors)
plt.show()

# %%
#bcancer.describe()
#bcancer.shape
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

x = np.array(bcancer[['compactness (nucB)']])
y = np.array(bcancer[['fractal dimension (nucB)']])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("compactness (nucB)", fontdict = font2)
plt.ylabel("fractal dimension (nucB)", fontdict = font2)
plt.title("compactness vs fractal dimension (nucB) (benign)", fontdict = font1)

colors = bcancer['diagnosis (M=malignant; B=benign)'].map({'B': 'blue', 'M': 'red'})

plt.scatter(x, y, color=colors)
plt.show()

# %%
## R-Squared : Checking any relationship between x and y
# if the value become 1 means having relationship
import numpy
from sklearn.metrics import r2_score

x1 = [int(i*100) for i in x]
y1 = [int(i*100) for i in y]
#print(x1)
#print(y1)
mymodel = numpy.poly1d(numpy.polyfit(x1, y1, 3))

print(r2_score(y1, mymodel(x1)))
# Out:
# 0.41148153087571926
# C:\Users\wilso\AppData\Local\Temp\ipykernel_25756\1384684369.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x1 = [int(i*100) for i in x]
# C:\Users\wilso\AppData\Local\Temp\ipykernel_25756\1384684369.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y1 = [int(i*100) for i in y]

# %%
x = np.array(bcancer[['radius (nucC)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'])
y = np.array(bcancer[['symmetry (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("radius (nucC)", fontdict = font2)
plt.ylabel("symmetry (nucA)", fontdict = font2)
plt.title("Radius vs symmetry (benign)", fontdict = font1)

plt.scatter(bcancer[['radius (nucC)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'], bcancer[['symmetry (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'])
plt.show()

# %%
x = np.array(bcancer[['radius (nucC)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'])
y = np.array(bcancer[['symmetry (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("radius (nucC)", fontdict = font2)
plt.ylabel("symmetry (nucA)", fontdict = font2)
plt.title("Radius vs symmetry (malignant)", fontdict = font1)

plt.scatter(bcancer[['radius (nucC)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'], bcancer[['symmetry (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'])
plt.show()

# %%
## compactness vs fractal dimension (benign)
import matplotlib.pyplot as plt
from scipy import stats

x = np.array(bcancer[['compactness (nucA)']])
y = np.array(bcancer[['fractal dimension (nucA)']])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("compactness (nucA)", fontdict = font2)
plt.ylabel("fractal dimension (nucA)", fontdict = font2)
plt.title("compactness vs fractal dimension (all)", fontdict = font1)

colors = bcancer['diagnosis (M=malignant; B=benign)'].map({'B': 'blue', 'M': 'red'})

plt.scatter(bcancer[['compactness (nucA)']], bcancer[['fractal dimension (nucA)']], color = colors)
plt.show()

# Below scatter plot could trying to build a machine learning to calculate the propability of malignant in simple measuring status

# %%
## compactness vs fractal dimension (benign)
import matplotlib.pyplot as plt
from scipy import stats

x = np.array(bcancer[['compactness (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'])
y = np.array(bcancer[['fractal dimension (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("compactness (nucA)", fontdict = font2)
plt.ylabel("fractal dimension (nucA)", fontdict = font2)
plt.title("compactness vs fractal dimension (benign)", fontdict = font1)

plt.scatter(bcancer[['compactness (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'], bcancer[['fractal dimension (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']=='B'])
plt.show()

# %%
## As this R-Squared value is too low
import numpy
from sklearn.metrics import r2_score

x1 = [int(i * 1000) for i in x]
y1 = [int(i * 1000) for i in y]

mymodel = numpy.poly1d(numpy.polyfit(x1, y1, 3))

print(r2_score(y1, mymodel(x1)))
# Out:
# 0.50021214886019
# C:\Users\wilso\AppData\Local\Temp\ipykernel_25756\2615288913.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x1 = [int(i * 1000) for i in x]
# C:\Users\wilso\AppData\Local\Temp\ipykernel_25756\2615288913.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y1 = [int(i * 1000) for i in y]

# %%
x = np.array(bcancer[['compactness (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'])
y = np.array(bcancer[['fractal dimension (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'])
#sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.xlabel("compactness (nucA)", fontdict = font2)
plt.ylabel("fractal dimension (nucA)", fontdict = font2)
plt.title("compactness vs fractal dimension (malignant)", fontdict = font1)

plt.scatter(bcancer[['compactness (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'], bcancer[['fractal dimension (nucA)']][bcancer['diagnosis (M=malignant; B=benign)']!='B'])
plt.show()

# %%
import numpy
from sklearn.metrics import r2_score

x1 = [int(i * 1000) for i in x]
y1 = [int(i * 1000) for i in y]

mymodel = numpy.poly1d(numpy.polyfit(x1, y1, 3))

print(r2_score(y1, mymodel(x1)))
# Out:
# 0.5770032703532997
# C:\Users\wilso\AppData\Local\Temp\ipykernel_25756\1498404216.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x1 = [int(i * 1000) for i in x]
# C:\Users\wilso\AppData\Local\Temp\ipykernel_25756\1498404216.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y1 = [int(i * 1000) for i in y]
